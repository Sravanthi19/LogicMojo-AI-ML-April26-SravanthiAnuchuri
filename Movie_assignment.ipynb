# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Movie+Assignment+Data (1).csv')

# %%
# Scale 'Gross' and 'budget' to millions, and 'MetaCritic' to a scale of 10
df['Gross'] = df['Gross'] / 1000000
df['budget'] = df['budget'] / 1000000
df['MetaCritic'] = df['MetaCritic'] / 10

# %%
# Check the number of rows and columns in the dataframe

df.shape
# Out:
# (100, 62)

# %%
# Check the column-wise info of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    float64
#  3   Gross                   100 non-null    float64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns
df.describe()
# Out:
#         title_year      budget       Gross  actor_1_facebook_likes  \
# count   100.000000  100.000000  100.000000              100.000000
# mean   2012.820000   78.384000  146.867867            13407.270000
# std       1.919491   74.452947  145.400370            10649.037862
# min    2010.000000    3.000000    0.223838               39.000000
# 25%    2011.000000   15.750000   41.997524             1000.000000
# 50%    2013.000000   42.250000  107.026591            13000.000000
# 75%    2014.000000  150.000000  210.754845            20000.000000
# max    2016.000000  260.000000  936.662225            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# min                 12.000000                0.000000     7.500000
# ...

# %%
# Check for null values in each column
df.isnull().sum()
# Out:
# Title             0
# title_year        0
# budget            0
# Gross             0
# actor_1_name      0
#                  ..
# Votes1000         0
# VotesUS           0
# VotesnUS          0
# content_rating    0
# Country           0
# Length: 62, dtype: int64

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column
df['profit'] = df['Gross'] - df['budget']
df
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'
df_sort_profit = df.sort_values(by = 'profit', ascending = False)
df_sort_profit
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# ..                                         ...         ...     ...
# 46                 Scott Pilgrim vs. the World        2010    60.0
# 7                                      Tangled        2010   260.0
# 17                            Edge of Tomorrow        2014   178.0
# 39                           The Little Prince        2015    81.2
# 22                                        Hugo        2011   170.0
#
#          Gross         actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225          Doug Walker         Rob Walker                      0
# ...

# %%
# Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)
top_movie = df_sort_profit.iloc[ :10]
top_movie
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
#Plot profit vs budget
# df.plot('profit','budget')
plt.scatter(df['profit'],df['budget'])

# %%
#Find the movies with negative profit
negative_movie = df[df['profit']<0]
negative_movie
# Out:
#                           Title  title_year  budget       Gross  \
# 7                       Tangled        2010   260.0  200.807262
# 17             Edge of Tomorrow        2014   178.0  100.189501
# 22                         Hugo        2011   170.0   73.820094
# 28           X-Men: First Class        2011   160.0  146.405371
# 39            The Little Prince        2015    81.2    1.339152
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270
# 56                         Rush        2013    38.0   26.903709
# 66                      Warrior        2011    25.0   13.651662
# 82                      Flipped        2010    14.0    1.752214
# 89                        Amour        2012     8.9    0.225377
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 7          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %% [markdown]
# # need clarification here like in the metacritics having null values

# %%
# Create a new column Avg_rating which will have the average of the MetaCritic and Rating columns

df['avg_ratings'] = (df['MetaCritic']+df['IMDb_rating'])/2

# %%
df
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
df['avg_ratings'].sort_values(ascending=False)
# Out:
# 94    8.95
# 69    8.85
# 18    8.80
# 12    8.75
# 0     8.75
#       ...
# 16     NaN
# 52     NaN
# 71     NaN
# 82     NaN
# 88     NaN
# Name: avg_ratings, Length: 100, dtype: float64

# %%
#  Find the movies with metacritic minus rating < 0.5 and also with the average rating of >8
movie = df[(df['MetaCritic']<8)&(df['avg_ratings']>8)]
movie
# Out:
#                     Title  title_year  budget       Gross       actor_1_name  \
# 8   The Dark Knight Rises        2012   250.0  448.130642          Tom Hardy
# 27              Inception        2010   160.0  292.568851  Leonardo DiCaprio
#
#       actor_2_name          actor_3_name  actor_1_facebook_likes  \
# 8   Christian Bale  Joseph Gordon-Levitt                   27000
# 27       Tom Hardy  Joseph Gordon-Levitt                   29000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes45A Votes45AM  \
# 8                  23000.0                 23000.0  ...       7.9       7.9
# 27                 27000.0                 23000.0  ...       8.1       8.1
#
#    Votes45AF Votes1000  VotesUS  VotesnUS  content_rating  Country  \
# 8        7.9       7.8      8.4       8.4           PG-13      USA
# 27       8.0       8.2      8.7       8.8           PG-13      USA
#
#         profit  avg_ratings
# 8   198.130642          8.1
# 27  132.568851          8.1
#
# ...

# %%
absolute_rating = df['avg_ratings'].abs()
absolute_rating
# Out:
# 0     8.75
# 1     7.95
# 2     7.50
# 3     8.05
# 4     8.75
#       ...
# 95    8.65
# 96    8.65
# 97    8.10
# 98    7.10
# 99    7.05
# Name: avg_ratings, Length: 100, dtype: float64

# %%
absolute_rating.sort_values(ascending=False)
# Out:
# 94    8.95
# 69    8.85
# 18    8.80
# 12    8.75
# 0     8.75
#       ...
# 16     NaN
# 52     NaN
# 71     NaN
# 82     NaN
# 88     NaN
# Name: avg_ratings, Length: 100, dtype: float64

# %%
# Sort these values in a descending order of Avg_rating and retain only the movies with a rating equal to higher than 8 and store these movies in a new dataframe UniversalAcclaim.

# %%
# Filter for movies with an average rating of 8 or higher
UniversalAcclaim = df[df['avg_ratings'] >= 8]

# Sort these movies by 'avg_ratings' in descending order
UniversalAcclaim = UniversalAcclaim.sort_values(by='avg_ratings', ascending=False)

# Display the resulting DataFrame
display(UniversalAcclaim)
# Out:
#                                               Title  title_year  budget  \
# 94                                          Boyhood        2014     4.0
# 69                                 12 Years a Slave        2013    20.0
# 18                                       Inside Out        2015   175.0
# 0                                        La La Land        2016    30.0
# 12                                      Toy Story 3        2010   200.0
# 4                             Manchester by the Sea        2016     9.0
# 34                                          Gravity        2013   100.0
# 70                                        Spotlight        2015    20.0
# 95                                         Whiplash        2014     3.3
# 89                                            Amour        2012     8.9
# 96                                  Before Midnight        2013     3.0
# 53                               The Social Network        2010    40.0
# ...

# %% [markdown]
# not find the starwars movie in results here

# %%
# Find the movies with metacritic-rating < 0.5 and also with the average rating of >8
movie = df[(df['MetaCritic']-df['']<0.5)&(df['avg_ratings']>8)]
movie
# Out:
# Empty DataFrame
# Columns: [Title, title_year, budget, Gross, actor_1_name, actor_2_name, actor_3_name, actor_1_facebook_likes, actor_2_facebook_likes, actor_3_facebook_likes, IMDb_rating, genre_1, genre_2, genre_3, MetaCritic, Runtime, CVotes10, CVotes09, CVotes08, CVotes07, CVotes06, CVotes05, CVotes04, CVotes03, CVotes02, CVotes01, CVotesMale, CVotesFemale, CVotesU18, CVotesU18M, CVotesU18F, CVotes1829, CVotes1829M, CVotes1829F, CVotes3044, CVotes3044M, CVotes3044F, CVotes45A, CVotes45AM, CVotes45AF, CVotes1000, CVotesUS, CVotesnUS, VotesM, VotesF, VotesU18, VotesU18M, VotesU18F, Votes1829, Votes1829M, Votes1829F, Votes3044, Votes3044M, Votes3044F, Votes45A, Votes45AM, Votes45AF, Votes1000, VotesUS, VotesnUS, content_rating, Country, profit, avg_ratings]
# Index: []
#
# [0 rows x 64 columns]

# %%
 #2.4
 df['top_likes'] = df['actor_1_facebook_likes'] + df['actor_2_facebook_likes'] + df['actor_3_facebook_likes']
 df['top_likes']
# Out:
# 0          NaN
# 1      57800.0
# 2     138800.0
# 3          NaN
# 4      74818.0
#         ...
# 95     25505.0
# 96       251.0
# 97       143.0
# 98     13000.0
# 99      2167.0
# Name: top_likes, Length: 100, dtype: float64

# %%
df['top_likes']=df['top_likes'].fillna(0)
df['top_likes']
# Out:
# 0          0.0
# 1      57800.0
# 2     138800.0
# 3          0.0
# 4      74818.0
#         ...
# 95     25505.0
# 96       251.0
# 97       143.0
# 98     13000.0
# 99      2167.0
# Name: top_likes, Length: 100, dtype: float64

# %%
#2.5

max_likes = df[['actor_1_facebook_likes']+['actor_2_facebook_likes']+['actor_3_facebook_likes']].max(axis=1)
max_likes
min_likes = df[['actor_1_facebook_likes']+['actor_2_facebook_likes']+['actor_3_facebook_likes']].min(axis=1)
min_likes
# Out:
# 0     14000.0
# 1      2800.0
# 2      9800.0
# 3      5300.0
# 4       518.0
#        ...
# 95      535.0
# 96       48.0
# 97        0.0
# 98     1000.0
# 99      440.0
# Length: 100, dtype: float64

# %%
trio_likes = df[min_likes >= (max_likes/2)]
trio_likes
# Out:
#                          Title  title_year  budget       Gross  \
# 0                   La La Land        2016    30.0  151.101803
# 8        The Dark Knight Rises        2012   250.0  448.130642
# 9   Captain America: Civil War        2016   250.0  407.197282
# 11                The Avengers        2012   220.0  623.279547
# 14  X-Men: Days of Future Past        2014   200.0  233.914986
# 23                  Big Hero 6        2014   165.0  222.487711
# 25              Wreck-It Ralph        2012   165.0  189.412677
# 26                Interstellar        2014   165.0  187.991439
# 27                   Inception        2010   160.0  292.568851
# 39           The Little Prince        2015    81.2    1.339152
# 43                   Gone Girl        2014    61.0  167.735396
# 44             Les MisÃ©rables        2012    61.0  148.775460
# 49                   Moneyball        2011    50.0   75.605492
# 51                        Argo        2012    44.5  136.019448
# ...

# %% [markdown]
# ## 1.No of trio = 21.
# # 2.most popular trio  = La La Land(Ryan Gosling	Emma Stone	Amiée Conn	)

# %% [markdown]
# ## Will try with if else statements after sometime

# %%
#  2.6 ploy histogram
sns.histplot(df['Runtime'])
# Out:
# <Axes: xlabel='Runtime', ylabel='Count'>

# %%
# 2.7 R- Rated movies

R_ratedmovies = df[df['content_rating']=='R']
R_ratedmovies
# Out:
#                                               Title  title_year  budget  \
# 4                             Manchester by the Sea        2016     9.0
# 5                                Hell or High Water        2016    12.0
# 29                               Mad Max: Fury Road        2015   150.0
# 31                                     The Revenant        2015   135.0
# 35                                 Django Unchained        2012   100.0
# 36                          The Wolf of Wall Street        2013   100.0
# 38                  The Girl with the Dragon Tattoo        2011    90.0
# 40                                   Shutter Island        2010    80.0
# 42                                             Fury        2014    68.0
# 43                                        Gone Girl        2014    61.0
# 47                                         Deadpool        2016    58.0
# 50                                        Prisoners        2013    46.0
# ...

# %%
populaR = R_ratedmovies[R_ratedmovies['CVotesU18']>0]
populaR
# Out:
#                                               Title  title_year  budget  \
# 4                             Manchester by the Sea        2016     9.0
# 5                                Hell or High Water        2016    12.0
# 29                               Mad Max: Fury Road        2015   150.0
# 31                                     The Revenant        2015   135.0
# 35                                 Django Unchained        2012   100.0
# 36                          The Wolf of Wall Street        2013   100.0
# 38                  The Girl with the Dragon Tattoo        2011    90.0
# 40                                   Shutter Island        2010    80.0
# 42                                             Fury        2014    68.0
# 43                                        Gone Girl        2014    61.0
# 47                                         Deadpool        2016    58.0
# 50                                        Prisoners        2013    46.0
# ...

# %%
populaR = populaR.sort_values(by = 'CVotesU18', ascending = False).head(10)
populaR
# Out:
#                                               Title  title_year  budget  \
# 47                                         Deadpool        2016    58.0
# 36                          The Wolf of Wall Street        2013   100.0
# 35                                 Django Unchained        2012   100.0
# 29                               Mad Max: Fury Road        2015   150.0
# 95                                         Whiplash        2014     3.3
# 31                                     The Revenant        2015   135.0
# 40                                   Shutter Island        2010    80.0
# 43                                        Gone Girl        2014    61.0
# 65                         The Grand Budapest Hotel        2014    25.0
# 72  Birdman or (The Unexpected Virtue of Ignorance)        2014    18.0
#
#          Gross       actor_1_name         actor_2_name       actor_3_name  \
# 47  363.024263      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# ...

# %%
genre_cols = ['genre_1', 'genre_2', 'genre_3']

cvotes_cols = [
    'CVotes10', 'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06',
    'CVotes05', 'CVotes04', 'CVotes03', 'CVotes02', 'CVotes01',
    'CVotesMale', 'CVotesFemale', 'CVotesU18', 'CVotesU18M', 'CVotesU18F',
    'CVotes1829', 'CVotes1829M', 'CVotes1829F', 'CVotes3044', 'CVotes3044M',
    'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF',
    'CVotes1000', 'CVotesUS', 'CVotesnUS'
]

votes_cols = [
    'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F',
    'Votes1829', 'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M',
    'Votes3044F', 'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000',
    'VotesUS', 'VotesnUS'
]

# Combine all desired columns
all_columns_for_df_by_genre = genre_cols + cvotes_cols + votes_cols

# Create the new DataFrame
df_by_genre = df[all_columns_for_df_by_genre]

print(f"Created df_by_genre with {len(df_by_genre.columns)} columns.")
display(df_by_genre.head())
# Out:
# Created df_by_genre with 47 columns.
#      genre_1    genre_2 genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0     Comedy      Drama   Music     74245     71191     64640     38831
# 1  Animation  Adventure  Comedy     53626     70912    102352     57261
# 2  Biography      Drama     NaN     23325     29830     40564     20296
# 3      Drama    Mystery  Sci-Fi     55533     87850    109536     65440
# 4      Drama        NaN     NaN     18191     33532     46596     29626
#
#    CVotes06  CVotes05  CVotes04  ...  Votes1829F  Votes3044  Votes3044M  \
# 0     17377      8044      3998  ...         8.2        7.9         7.9
# 1     16719      4539      1467  ...         8.4        7.8         7.8
# 2      5842      1669       558  ...         8.4        8.0         7.9
# 3     26913     10556      5057  ...         8.1        7.8         7.8
# 4     11879      4539      1976  ...         7.8        7.7         7.7
#
# ...

# %%
df_by_genre.shape
# Out:
# (100, 47)

# %%
df_by_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 47 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genre_1       100 non-null    object
#  1   genre_2       97 non-null     object
#  2   genre_3       74 non-null     object
#  3   CVotes10      100 non-null    int64
#  4   CVotes09      100 non-null    int64
#  5   CVotes08      100 non-null    int64
#  6   CVotes07      100 non-null    int64
#  7   CVotes06      100 non-null    int64
#  8   CVotes05      100 non-null    int64
#  9   CVotes04      100 non-null    int64
#  10  CVotes03      100 non-null    int64
#  11  CVotes02      100 non-null    int64
#  12  CVotes01      100 non-null    int64
#  13  CVotesMale    100 non-null    int64
#  14  CVotesFemale  100 non-null    int64
#  15  CVotesU18     100 non-null    int64
#  16  CVotesU18M    100 non-null    int64
#  17  CVotesU18F    100 non-null    int64
# ...

# %%
df_by_genre['cnt'] = 1
display(df_by_genre.head())
# Out:
#      genre_1    genre_2 genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0     Comedy      Drama   Music     74245     71191     64640     38831
# 1  Animation  Adventure  Comedy     53626     70912    102352     57261
# 2  Biography      Drama     NaN     23325     29830     40564     20296
# 3      Drama    Mystery  Sci-Fi     55533     87850    109536     65440
# 4      Drama        NaN     NaN     18191     33532     46596     29626
#
#    CVotes06  CVotes05  CVotes04  ...  Votes3044  Votes3044M  Votes3044F  \
# 0     17377      8044      3998  ...        7.9         7.9         7.8
# 1     16719      4539      1467  ...        7.8         7.8         8.1
# 2      5842      1669       558  ...        8.0         7.9         8.2
# 3     26913     10556      5057  ...        7.8         7.8         7.8
# 4     11879      4539      1976  ...        7.7         7.7         7.7
#
#    Votes45A  Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  cnt
# ...

# %%
numeric_cols = [col for col in df_by_genre.columns if col not in ['genre_1', 'genre_2', 'genre_3']]
df_by_g1 = df_by_genre.groupby('genre_1')[numeric_cols].sum()
display(df_by_g1.head())
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# Animation     30718     15733     10026     25193  ...       85.4        84.9
# Biography     38874     21536     15365     37469  ...      100.8       100.7
# Comedy        35788     20965     15286     33241  ...       68.6        68.7
#
# ...

# %%
df_by_g2 = df_by_genre.groupby('genre_2')[numeric_cols].sum()
display(df_by_g2.head())
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_2                                            ...
# Action        10820      5521      3598      8821  ...       30.9        30.7
# Adventure    113691     64623     44121    116937  ...      171.0       170.4
# Biography     14844      7974      5248     13828  ...       38.3        38.2
# Comedy        35193     20995     14798     30509  ...       54.0        54.1
# Crime          3261      1669       970      1689  ...        7.5         7.6
#
# ...

# %%
df_by_g3 = df_by_genre.groupby('genre_3')[numeric_cols].sum()
display(df_by_g3.head())
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_3                                            ...
# Adventure     10820      5521      3598      8821  ...       30.9        30.7
# Comedy        26488     14258      9307     24617  ...       54.8        54.6
# Crime          8674      5854      4258      9689  ...        8.0         8.1
# Drama         35439     19075     12475     26948  ...       91.8        91.7
# Family         4664      2674      1700      3023  ...        7.4         7.4
#
# ...

# %%
df_add = df_by_g1.add(df_by_g2, fill_value=0).add(df_by_g3, fill_value=0)
display(df_add.head())
# df_add = df_add.reset_index()
# df_add.rename(columns={'index': 'genre'}, inplace=True)
# display(df_add.head())
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action     166970.0   95004.0   65573.0  171247.0  ...      240.0       239.5
# Adventure  183070.0  103318.0   69737.0  173858.0  ...      294.6       293.7
# Animation   30718.0   15733.0   10026.0   25193.0  ...       85.4        84.9
# Biography   53718.0   29510.0   20613.0   51297.0  ...      139.1       138.9
# Comedy      97469.0   56218.0   39391.0   88367.0  ...      177.4       177.4
#
# ...

# %%
# Subset genres that have at least 10 movies based on the 'cnt' column
genre_top10 = df_add[df_add['cnt'] >= 10]

display(genre_top10.head())
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action     166970.0   95004.0   65573.0  171247.0  ...      240.0       239.5
# Adventure  183070.0  103318.0   69737.0  173858.0  ...      294.6       293.7
# Animation   30718.0   15733.0   10026.0   25193.0  ...       85.4        84.9
# Biography   53718.0   29510.0   20613.0   51297.0  ...      139.1       138.9
# Comedy      97469.0   56218.0   39391.0   88367.0  ...      177.4       177.4
#
# ...

# %%
# Identify numeric columns for which to calculate the mean, excluding 'genre' and 'cnt'
numeric_cols_for_mean = [col for col in genre_top10.columns if genre_top10[col].dtype in ['int64', 'float64'] and col not in ['cnt']]

# Reset the index to make 'genre' a column
genre_top10 = genre_top10.reset_index()
genre_top10.rename(columns={'index': 'genre'}, inplace=True)

# Calculate the mean for these columns by dividing by 'cnt'
genre_top10_mean = genre_top10[['genre', 'cnt']].copy()
genre_top10_mean[numeric_cols_for_mean] = genre_top10[numeric_cols_for_mean].div(genre_top10['cnt'], axis=0)

# Display the resulting DataFrame with mean values
display(genre_top10_mean.head())
# Out:
#        genre   cnt       CVotes10       CVotes09       CVotes08      CVotes07  \
# 0     Action  31.0  102144.096774  114433.193548  150895.322581  94262.129032
# 1  Adventure  38.0   94596.289474  105636.631579  138482.315789  86367.921053
# 2  Animation  11.0   61960.181818   72566.090909  104837.636364  65707.454545
# 3  Biography  18.0   47333.500000   77867.111111  123948.777778  74054.444444
# 4     Comedy  23.0   60157.217391   77173.347826  108993.521739  69176.913043
#
#        CVotes06      CVotes05     CVotes04     CVotes03  ...  Votes1829F  \
# 0  34688.838710  12693.032258  5386.129032  3064.645161  ...    8.000000
# 1  31896.710526  11551.842105  4817.631579  2718.894737  ...    8.086842
# 2  22825.090909   7551.727273  2792.545455  1430.272727  ...    8.200000
# 3  23644.166667   7702.666667  2984.333333  1639.444444  ...    7.933333
# 4  26099.434783   9863.130435  4237.782609  2444.260870  ...    7.947826
#
# ...

# %%
 genre_top10_mean.round(2)
 genre_top10_mean
# Out:
#        genre   cnt       CVotes10       CVotes09       CVotes08  \
# 0     Action  31.0  102144.096774  114433.193548  150895.322581
# 1  Adventure  38.0   94596.289474  105636.631579  138482.315789
# 2  Animation  11.0   61960.181818   72566.090909  104837.636364
# 3  Biography  18.0   47333.500000   77867.111111  123948.777778
# 4     Comedy  23.0   60157.217391   77173.347826  108993.521739
# 5      Crime  11.0   52229.636364   87919.818182  129045.000000
# 6      Drama  65.0   52375.969231   75928.846154  109339.276923
# 7    Romance  13.0   42304.538462   53037.846154   82252.307692
# 8     Sci-Fi  17.0  136781.411765  148873.823529  176646.705882
# 9   Thriller  13.0   83207.769231  112730.076923  153336.769231
#
#         CVotes07      CVotes06      CVotes05     CVotes04     CVotes03  ...  \
# 0   94262.129032  34688.838710  12693.032258  5386.129032  3064.645161  ...
# 1   86367.921053  31896.710526  11551.842105  4817.631579  2718.894737  ...
# ...

# %%
# Identify 'Votes' columns to round
votes_columns_to_round = [
    'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F',
    'Votes1829', 'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M',
    'Votes3044F', 'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000',
    'VotesUS', 'VotesnUS'
]

# Round the specified 'Votes' columns to two decimal places
genre_top10_mean[votes_columns_to_round] = genre_top10_mean[votes_columns_to_round].round(2)

# Display the updated DataFrame
display(genre_top10_mean.head())
# Out:
#        genre   cnt       CVotes10       CVotes09       CVotes08      CVotes07  \
# 0     Action  31.0  102144.096774  114433.193548  150895.322581  94262.129032
# 1  Adventure  38.0   94596.289474  105636.631579  138482.315789  86367.921053
# 2  Animation  11.0   61960.181818   72566.090909  104837.636364  65707.454545
# 3  Biography  18.0   47333.500000   77867.111111  123948.777778  74054.444444
# 4     Comedy  23.0   60157.217391   77173.347826  108993.521739  69176.913043
#
#        CVotes06      CVotes05     CVotes04     CVotes03  ...  Votes1829F  \
# 0  34688.838710  12693.032258  5386.129032  3064.645161  ...        8.00
# 1  31896.710526  11551.842105  4817.631579  2718.894737  ...        8.09
# 2  22825.090909   7551.727273  2792.545455  1430.272727  ...        8.20
# 3  23644.166667   7702.666667  2984.333333  1639.444444  ...        7.93
# 4  26099.434783   9863.130435  4237.782609  2444.260870  ...        7.95
#
# ...

# %%
# Identify 'CVotes' columns (excluding 'cnt' and 'genre' if they were accidentally included by numeric_cols_for_mean)
cvotes_cols_in_mean = [col for col in genre_top10_mean.columns if 'CVotes' in col]

# Convert identified 'CVotes' columns to integer type
for col in cvotes_cols_in_mean:
    genre_top10_mean[col] = genre_top10_mean[col].astype(int)

# Display the updated DataFrame to show the changes
display(genre_top10_mean.head())
# Out:
#        genre   cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  \
# 0     Action  31.0    102144    114433    150895     94262     34688
# 1  Adventure  38.0     94596    105636    138482     86367     31896
# 2  Animation  11.0     61960     72566    104837     65707     22825
# 3  Biography  18.0     47333     77867    123948     74054     23644
# 4     Comedy  23.0     60157     77173    108993     69176     26099
#
#    CVotes05  CVotes04  CVotes03  ...  Votes1829F  Votes3044  Votes3044M  \
# 0     12693      5386      3064  ...        8.00       7.74        7.73
# 1     11551      4817      2718  ...        8.09       7.75        7.73
# 2      7551      2792      1430  ...        8.20       7.76        7.72
# 3      7702      2984      1639  ...        7.93       7.73        7.72
# 4      9863      4237      2444  ...        7.95       7.71        7.71
#
#    Votes3044F  Votes45A  Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='genre', y='cnt', data=genre_top10_mean, palette='viridis')
plt.title('Count of Movies per Genre (Top 10 Genres by Count)')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Select the relevant columns for the heatmap
male_votes_cols = ['CVotesU18M', 'CVotes1829M', 'CVotes3044M', 'CVotes45AM']
heatmap_data = genre_top10_mean.set_index('genre')[male_votes_cols]

# Create the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='viridis')
plt.title('Average Male Votes Across Age Groups per Genre')
plt.xlabel('Male Age Groups')
plt.ylabel('Genre')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Average Female Votes Across Age Groups per Genre Heatmap

# %%
male_votes_cols = ['CVotesU18M', 'CVotes1829M', 'CVotes3044M', 'CVotes45AM']
# Select the relevant columns for the heatmap for female votes
female_votes_cols = ['CVotesU18F', 'CVotes1829F', 'CVotes3044F', 'CVotes45AF']
heatmap_data_female = genre_top10_mean.set_index('genre')[female_votes_cols]

# Create the heatmap for female votes
plt.figure(figsize=(10, 7))
sns.heatmap(heatmap_data_female, annot=True, fmt='d', cmap='magma')
plt.title('Average Female Votes Across Age Groups per Genre')
plt.xlabel('Female Age Groups')
plt.ylabel('Genre')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
